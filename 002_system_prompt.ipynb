# %%
# %pip install anthropic python-dotenv

# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model" : model,
        "max_tokens" : 1000,
        "messages" : messages,
        "temperature" : temperature
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3+2 for x?")

system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """

answer = chat(messages, system=system)

answer
# Out:
# "I want to make sure we set you up for success here! I notice something important about what you've written.\n\n**5x + 3 + 2** is actually an **expression**, not an **equation**.\n\nTo *solve for x*, we need an **equation** — something with an **equals sign (=)**.\n\nFor example:\n- 5x + 3 + 2 = **0**\n- 5x + 3 + 2 = **10**\n\nCan you double-check your problem? Is there an equals sign and a number on the other side? Once you share the full equation, I can guide you through solving it step by step! 😊"

# %%
messages = []

add_user_message(messages, "Generate a one sentence movie idea")

answer = chat(messages, temperature=1.0)

answer
# Out:
# "Here's a movie idea:\n\n**A retired safecracker with early-onset dementia must break into a bank to retrieve a locket containing the only photo of his late wife before he forgets her face forever.**"
